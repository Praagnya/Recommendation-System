# %%
# Importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from collections import defaultdict
from surprise import SVD
from surprise import KNNWithMeans
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

# Suppressing Warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fbdf1d8ee892> in <module>
#       7 from sklearn import preprocessing
#       8 from collections import defaultdict
# ----> 9 from surprise import SVD
#      10 from surprise import KNNWithMeans
#      11 from surprise import Dataset
#
# ModuleNotFoundError: No module named 'surprise'

# %%
# !pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Using cached https://files.pythonhosted.org/packages/97/37/5d334adaf5ddd65da99fc65f6507e0e4599d092ba048f4302fe8775619e8/scikit-surprise-1.1.1.tar.gz
# Requirement already satisfied: joblib>=0.11 in c:\users\pragnya\anaconda3\lib\site-packages (from scikit-surprise) (0.14.0)
# Requirement already satisfied: numpy>=1.11.2 in c:\users\pragnya\anaconda3\lib\site-packages (from scikit-surprise) (1.16.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\pragnya\anaconda3\lib\site-packages (from scikit-surprise) (1.2.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\pragnya\anaconda3\lib\site-packages (from scikit-surprise) (1.12.0)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py): started
#   Building wheel for scikit-surprise (setup.py): finished with status 'error'
#   Complete output from command C:\Users\Pragnya\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Pragnya\\AppData\\Local\\Temp\\pip-install-z1gqurt2\\scikit-surprise\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\Pragnya\AppData\Local\Temp\pip-wheel-jfs5kh3_ --python-tag cp37:
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.7
#   creating build\lib.win-amd64-3.7\surprise
#   copying surprise\accuracy.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\builtin_datasets.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\dataset.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\dump.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\reader.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\trainset.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\utils.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\__init__.py -> build\lib.win-amd64-3.7\surprise
#   copying surprise\__main__.py -> build\lib.win-amd64-3.7\surprise
#   creating build\lib.win-amd64-3.7\surprise\model_selection
#   copying surprise\model_selection\search.py -> build\lib.win-amd64-3.7\surprise\model_selection
#   copying surprise\model_selection\split.py -> build\lib.win-amd64-3.7\surprise\model_selection
#   copying surprise\model_selection\validation.py -> build\lib.win-amd64-3.7\surprise\model_selection
#   copying surprise\model_selection\__init__.py -> build\lib.win-amd64-3.7\surprise\model_selection
#   creating build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\algo_base.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\baseline_only.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\knns.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\predictions.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\random_pred.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\__init__.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   running egg_info
#   writing scikit_surprise.egg-info\PKG-INFO
#   writing dependency_links to scikit_surprise.egg-info\dependency_links.txt
#   writing entry points to scikit_surprise.egg-info\entry_points.txt
#   writing requirements to scikit_surprise.egg-info\requires.txt
#   writing top-level names to scikit_surprise.egg-info\top_level.txt
#   reading manifest file 'scikit_surprise.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   writing manifest file 'scikit_surprise.egg-info\SOURCES.txt'
#   copying surprise\similarities.c -> build\lib.win-amd64-3.7\surprise
#   copying surprise\similarities.pyx -> build\lib.win-amd64-3.7\surprise
#   copying surprise\prediction_algorithms\co_clustering.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\matrix_factorization.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\optimize_baselines.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\slope_one.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\co_clustering.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\matrix_factorization.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\optimize_baselines.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   copying surprise\prediction_algorithms\slope_one.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#   running build_ext
#   building 'surprise.similarities' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#
#   ----------------------------------------
#   Running setup.py clean for scikit-surprise
# Failed to build scikit-surprise
# Installing collected packages: scikit-surprise
#   Running setup.py install for scikit-surprise: started
#     Running setup.py install for scikit-surprise: finished with status 'error'
#     Complete output from command C:\Users\Pragnya\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Pragnya\\AppData\\Local\\Temp\\pip-install-z1gqurt2\\scikit-surprise\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\Pragnya\AppData\Local\Temp\pip-record-m7g9a8w6\install-record.txt --single-version-externally-managed --compile:
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.7
#     creating build\lib.win-amd64-3.7\surprise
#     copying surprise\accuracy.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\builtin_datasets.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\dataset.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\dump.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\reader.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\trainset.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\utils.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\__init__.py -> build\lib.win-amd64-3.7\surprise
#     copying surprise\__main__.py -> build\lib.win-amd64-3.7\surprise
#     creating build\lib.win-amd64-3.7\surprise\model_selection
#     copying surprise\model_selection\search.py -> build\lib.win-amd64-3.7\surprise\model_selection
#     copying surprise\model_selection\split.py -> build\lib.win-amd64-3.7\surprise\model_selection
#     copying surprise\model_selection\validation.py -> build\lib.win-amd64-3.7\surprise\model_selection
#     copying surprise\model_selection\__init__.py -> build\lib.win-amd64-3.7\surprise\model_selection
#     creating build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\algo_base.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\baseline_only.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\knns.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\predictions.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\random_pred.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\__init__.py -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     running egg_info
#     writing scikit_surprise.egg-info\PKG-INFO
#     writing dependency_links to scikit_surprise.egg-info\dependency_links.txt
#     writing entry points to scikit_surprise.egg-info\entry_points.txt
#     writing requirements to scikit_surprise.egg-info\requires.txt
#     writing top-level names to scikit_surprise.egg-info\top_level.txt
#     reading manifest file 'scikit_surprise.egg-info\SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     writing manifest file 'scikit_surprise.egg-info\SOURCES.txt'
#     copying surprise\similarities.c -> build\lib.win-amd64-3.7\surprise
#     copying surprise\similarities.pyx -> build\lib.win-amd64-3.7\surprise
#     copying surprise\prediction_algorithms\co_clustering.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\matrix_factorization.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\optimize_baselines.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\slope_one.c -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\co_clustering.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\matrix_factorization.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\optimize_baselines.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     copying surprise\prediction_algorithms\slope_one.pyx -> build\lib.win-amd64-3.7\surprise\prediction_algorithms
#     running build_ext
#     building 'surprise.similarities' extension
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Build Tools for Visual Studio": https://visualstudio.microsoft.com/downloads/
#
#     ----------------------------------------
#   Failed building wheel for scikit-surprise
# Command "C:\Users\Pragnya\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\Pragnya\\AppData\\Local\\Temp\\pip-install-z1gqurt2\\scikit-surprise\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\Pragnya\AppData\Local\Temp\pip-record-m7g9a8w6\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\Pragnya\AppData\Local\Temp\pip-install-z1gqurt2\scikit-surprise\

# %%
df1 = pd.read_csv('phone_user_review_file_1.csv',engine = 'python')
df2 = pd.read_csv('phone_user_review_file_2.csv',engine = 'python')
df3 = pd.read_csv('phone_user_review_file_3.csv',engine = 'python')
df4 = pd.read_csv('phone_user_review_file_4.csv',engine = 'python')
df5 = pd.read_csv('phone_user_review_file_5.csv',engine = 'python')
df6 = pd.read_csv('phone_user_review_file_6.csv',engine = 'python')

# %%
df1.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-ba1842de51e0> in <module>
# ----> 1 df1.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df2
# Out:
#                                   phone_url        date lang country  \
# 0                /cellphones/leagoo-lead-7/   4/15/2015   en      us
# 1                /cellphones/leagoo-lead-7/   5/23/2015   en      gb
# 2                /cellphones/leagoo-lead-7/   4/27/2015   en      gb
# 3                /cellphones/leagoo-lead-7/   4/22/2015   en      gb
# 4                /cellphones/leagoo-lead-7/   4/18/2015   en      gb
# 5                /cellphones/leagoo-lead-7/   4/14/2015   en      us
# 6                /cellphones/leagoo-lead-7/    4/1/2015   en      gb
# 7                /cellphones/leagoo-lead-7/   11/6/2015   it      it
# 8                /cellphones/leagoo-lead-7/  10/26/2015   it      it
# 9                /cellphones/leagoo-lead-7/   9/19/2015   it      it
# 10               /cellphones/leagoo-lead-7/    8/1/2015   es      es
# 11               /cellphones/leagoo-lead-7/   7/13/2015   es      es
# 12               /cellphones/leagoo-lead-7/   6/25/2015   it      it
# 13               /cellphones/leagoo-lead-7/   6/24/2015   it      it
# 14               /cellphones/leagoo-lead-7/    4/7/2015   pt      pt
# 15               /cellphones/leagoo-lead-7/    4/7/2015   pt      pt
# 16               /cellphones/leagoo-lead-7/    4/7/2015   pt      pt
# 17               /cellphones/leagoo-lead-7/    4/7/2015   pt      pt
# 18               /cellphones/leagoo-lead-7/    4/7/2015   pt      pt
# 19                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 20                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 21                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 22                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 23                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 24                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 25                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 26                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 27                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 28                   /cellphones/thl-2015a/  11/17/2015   en      gb
# 29                   /cellphones/thl-2015a/  11/17/2015   en      gb
# ...                                     ...         ...  ...     ...
# 114895  /cellphones/motorola-moto-g-4-plus/   9/27/2016   en      us
# 114896  /cellphones/motorola-moto-g-4-plus/   9/26/2016   en      us
# 114897  /cellphones/motorola-moto-g-4-plus/   9/22/2016   en      us
# 114898  /cellphones/motorola-moto-g-4-plus/   9/19/2016   en      us
# 114899  /cellphones/motorola-moto-g-4-plus/   9/18/2016   en      us
# 114900  /cellphones/motorola-moto-g-4-plus/   9/14/2016   en      ca
# 114901  /cellphones/motorola-moto-g-4-plus/   9/12/2016   en      us
# 114902  /cellphones/motorola-moto-g-4-plus/   9/11/2016   en      us
# 114903  /cellphones/motorola-moto-g-4-plus/   9/11/2016   en      au
# 114904  /cellphones/motorola-moto-g-4-plus/    9/7/2016   en      us
# 114905  /cellphones/motorola-moto-g-4-plus/   8/29/2016   en      us
# 114906  /cellphones/motorola-moto-g-4-plus/   8/29/2016   en      ca
# 114907  /cellphones/motorola-moto-g-4-plus/   8/29/2016   en      ca
# 114908  /cellphones/motorola-moto-g-4-plus/   8/27/2016   en      au
# 114909  /cellphones/motorola-moto-g-4-plus/   8/24/2016   en      au
# 114910  /cellphones/motorola-moto-g-4-plus/   8/23/2016   en      us
# 114911  /cellphones/motorola-moto-g-4-plus/   8/21/2016   en      au
# 114912  /cellphones/motorola-moto-g-4-plus/   8/21/2016   en      au
# 114913  /cellphones/motorola-moto-g-4-plus/   8/20/2016   en      au
# 114914  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114915  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114916  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114917  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114918  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114919  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114920  /cellphones/motorola-moto-g-4-plus/   8/19/2016   en      in
# 114921  /cellphones/motorola-moto-g-4-plus/   8/18/2016   en      in
# 114922  /cellphones/motorola-moto-g-4-plus/   8/18/2016   en      in
# 114923  /cellphones/motorola-moto-g-4-plus/   8/18/2016   en      in
# 114924  /cellphones/motorola-moto-g-4-plus/   8/18/2016   en      in
#
#                source              domain  score  score_max  \
# 0              Amazon          amazon.com    2.0       10.0
# 1              Amazon        amazon.co.uk   10.0       10.0
# 2              Amazon        amazon.co.uk    8.0       10.0
# 3              Amazon        amazon.co.uk   10.0       10.0
# 4              Amazon        amazon.co.uk   10.0       10.0
# 5              Amazon          amazon.com   10.0       10.0
# 6              Amazon        amazon.co.uk   10.0       10.0
# 7              Amazon           amazon.it   10.0       10.0
# 8              Amazon           amazon.it   10.0       10.0
# 9              Amazon           amazon.it   10.0       10.0
# 10             Amazon           amazon.es   10.0       10.0
# 11             Amazon           amazon.es    4.0       10.0
# 12             Amazon           amazon.it   10.0       10.0
# 13             Amazon           amazon.it   10.0       10.0
# 14               Efox         efox.com.pt    9.3       10.0
# 15               Efox         efox.com.pt    9.3       10.0
# 16               Efox         efox.com.pt    8.0       10.0
# 17               Efox         efox.com.pt    8.7       10.0
# 18               Efox         efox.com.pt    8.0       10.0
# 19             Amazon        amazon.co.uk   10.0       10.0
# 20             Amazon        amazon.co.uk    2.0       10.0
# 21             Amazon        amazon.co.uk   10.0       10.0
# 22             Amazon        amazon.co.uk    8.0       10.0
# 23             Amazon        amazon.co.uk    8.0       10.0
# 24             Amazon        amazon.co.uk   10.0       10.0
# 25             Amazon        amazon.co.uk   10.0       10.0
# 26             Amazon        amazon.co.uk   10.0       10.0
# 27             Amazon        amazon.co.uk   10.0       10.0
# 28             Amazon        amazon.co.uk   10.0       10.0
# 29             Amazon        amazon.co.uk    2.0       10.0
# ...               ...                 ...    ...        ...
# 114895      B&H Photo    bhphotovideo.com    8.0       10.0
# 114896      B&H Photo    bhphotovideo.com   10.0       10.0
# 114897      B&H Photo    bhphotovideo.com   10.0       10.0
# 114898      B&H Photo    bhphotovideo.com    8.0       10.0
# 114899      B&H Photo    bhphotovideo.com    8.0       10.0
# 114900         Amazon           amazon.ca   10.0       10.0
# 114901      B&H Photo    bhphotovideo.com   10.0       10.0
# 114902      B&H Photo    bhphotovideo.com   10.0       10.0
# 114903  The Good Guys  thegoodguys.com.au    9.0       10.0
# 114904      B&H Photo    bhphotovideo.com   10.0       10.0
# 114905      B&H Photo    bhphotovideo.com   10.0       10.0
# 114906         Amazon           amazon.ca    8.0       10.0
# 114907         Amazon           amazon.ca    8.0       10.0
# 114908  The Good Guys  thegoodguys.com.au    8.0       10.0
# 114909  The Good Guys  thegoodguys.com.au    9.0       10.0
# 114910      B&H Photo    bhphotovideo.com   10.0       10.0
# 114911  The Good Guys  thegoodguys.com.au    8.0       10.0
# 114912  The Good Guys  thegoodguys.com.au   10.0       10.0
# 114913  The Good Guys  thegoodguys.com.au   10.0       10.0
# 114914         Amazon           amazon.in   10.0       10.0
# 114915         Amazon           amazon.in    2.0       10.0
# 114916         Amazon           amazon.in    2.0       10.0
# 114917         Amazon           amazon.in   10.0       10.0
# 114918         Amazon           amazon.in    2.0       10.0
# 114919         Amazon           amazon.in   10.0       10.0
# 114920         Amazon           amazon.in    2.0       10.0
# 114921         Amazon           amazon.in    2.0       10.0
# 114922         Amazon           amazon.in   10.0       10.0
# 114923         Amazon           amazon.in    8.0       10.0
# 114924         Amazon           amazon.in    6.0       10.0
#
#                                                   extract             author  \
# 0       The telephone headset is of poor quality , not...               luis
# 1       This is my first smartphone so I have nothing ...         Mark Lavin
# 2       Great phone. Battery life not great but seems ...             tracey
# 3           Best 90 quid I've ever spent on a smart phone      Reuben Ingram
# 4       I m happy with this phone.it s very good.thx team             viorel
# 5       Exelent phone. Evriting perfect. Service is am...             Milena
# 6       Great mobile, but contains malware, in the for...        lee carroll
# 7       maneggevole, pratico, veloce, ottime foto........         Filippo L.
# 8       Prodotto ECCELLENTE!!! Praticamente perfetto, ...        Emiliano S.
# 9       Cercavo un telefono che avesse una fotocamera ...            rossano
# 10      Movil calidad precio inmejorable, la baterÃ­a ...               jose
# 11      Problemas con el sonido tanto para hablar como...              Angel
# 12      acquistato scontato a 127 euro circa, prodotto...          francesca
# 13      Forse un po' troppo premurosa Leagoo a montare...           Fabrizio
# 14                Custo beneficio excelente, vale a pena.              Romeu
# 15      O aparelho Ã© mto bom. Estou com ele hÃ¡ duas ...              jader
# 16      Telefone e embalagem design agradÃ¡vel. agradÃ...              andre
# 17      4500mAh alta densidade bateria de polÃ­mero de...            Armindo
# 18      Minha Ãºnica ressalva Ã© o fato de ter menos c...             Filipe
# 19      Brilliant phone, surfing is rapid on 4g, takes...           Mr Croft
# 20      Bought this 6 months ago. Was completely brill...   Alison Colquhoun
# 21      Totally brilliant phone for the money. HD scre...           Kayakman
# 22      Like the mobile. but more complicated to set u...            beverly
# 23      Good phone that does everything I need. Excell...              JR888
# 24      This is my wife's phone and she said she would...      Mike Warville
# 25                 Has the phone a while now, great phone    Amazon Customer
# 26      Fantastic phone! Very good value for that pric...     boredhousewife
# 27      Arrrived very quickly and exactly as described...     Patricia Dunne
# 28      Great phone, good battery, fast and all aps wo...          martin l.
# 29      Actually I can't really rate it at all but I h...        Edith Crisp
# ...                                                   ...                ...
# 114895  With one exception this does essentially every...             WallyD
# 114896  I have always used Iphones so it took a little...            Ricky M
# 114897  This phone, overall, is a good product when yo...              BArto
# 114898  It appears to me you can do almost everything ...              Wally
# 114899  I came in looking for a replacement for a Sams...             Trevor
# 114900  Performs as expected and advertised. It is a v...    Amazon Customer
# 114901  I have always used Iphones but price is gettin...            Richard
# 114902  I like the shape of the phone, it does not com...  Mewithelectronics
# 114903                                                NaN          RAMANJEET
# 114904  Why spent $800 dollars on an iPhone (overprice...         Tiger Hits
# 114905                         So far, no problems happen                  L
# 114906  I love it. Fast and lovely big screen. Like th...      Yvonne Sommer
# 114907      Bought for my son who is very happy so far :)     Faisal Hassany
# 114908                                                NaN             ANDREW
# 114909                                                NaN               RYAN
# 114910          Its a good smarthphone with a good price.                Alu
# 114911                                                NaN              LIDIA
# 114912                                                NaN            CAMERON
# 114913                                                NaN            LINDSAY
# 114914            Battery life is excellent, simple phone      Abhishek Soni
# 114915         Using from 3 months, battery drains early.    Amazon Customer
# 114916  It worked well for about six months but after ...              Bijee
# 114917  Just go for it. Almost a year and the phone is...    Amazon Customer
# 114918  Worst mobile I have ever purchased. It's scree...               gaji
# 114919  Motorola is a name globally identified and 100...   Ashok Kumar Jena
# 114920  It's getting problem when both sim working tog...        raj agrawal
# 114921  Hopeless phone. Not at all user friendly. Woul...    Amazon Customer
# 114922                                   Very nice phone.    Amazon Customer
# 114923  Over all good phone . Give all the specificati...    Amazon Customer
# 114924  I bought Moto G Plus last month.. Camera and m...        Venkidusami
#
#                                                   product
# 0       Leagoo Lead7 5.0 Inch HD JDI LTPS Screen 3G Sm...
# 1       Leagoo Lead 7 Lead7 MTK6582 Quad core 1GB RAM ...
# 2       Leagoo Lead 7 Lead7 MTK6582 Quad core 1GB RAM ...
# 3       Leagoo Lead 7 Lead7 MTK6582 Quad core 1GB RAM ...
# 4       Leagoo Lead 7 Lead7 MTK6582 Quad core 1GB RAM ...
# 5       Leagoo Lead7 5.0 Inch HD JDI LTPS Screen 3G Sm...
# 6       Leagoo Lead 7 Lead7 MTK6582 Quad core 1GB RAM ...
# 7       LEAGOO Lead 7 MTK6582 Quad Core 5" Pollice Sma...
# 8       LEAGOO Lead 7 MTK6582 Quad Core 5" Pollice Sma...
# 9       LEAGOO Lead 7 MTK6582 Quad Core 5" Pollice Sma...
# 10      Leagoo Lead 7 MTK6582 5" Pulgadas del TelÃ©fon...
# 11      Leagoo Lead 7 MTK6582 5" Pulgadas del TelÃ©fon...
# 12      LEAGOO Lead 7 MTK6582 Quad Core 5" Pollice Sma...
# 13      LEAGOO Lead 7 MTK6582 Quad Core 5" Pollice Sma...
# 14      LEAGOO LEAD 7 MTK6582 1.3GHz Quad Core Bateria...
# 15      LEAGOO LEAD 7 MTK6582 1.3GHz Quad Core Bateria...
# 16      LEAGOO LEAD 7 MTK6582 1.3GHz Quad Core Bateria...
# 17      LEAGOO LEAD 7 MTK6582 1.3GHz Quad Core Bateria...
# 18      LEAGOO LEAD 7 MTK6582 1.3GHz Quad Core Bateria...
# 19      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 20      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 21      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 22      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 23      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 24      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 25      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 26      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 27      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 28      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# 29      THL Upgraded THL 2015A 5.0" IPS Android 5.1 Un...
# ...                                                   ...
# 114895  Moto G Plus XT1644 4th Gen. 16GB Smartphone (U...
# 114896  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114897  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114898  Moto G Plus XT1644 4th Gen. 16GB Smartphone (U...
# 114899  Moto G Plus XT1644 4th Gen. 16GB Smartphone (U...
# 114900   Motorola 'Moto G4 PLUS' (XT1641) Black, UNLOCKED
# 114901  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114902  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114903                     Motorola Moto G 4 Plus - Black
# 114904  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114905  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114906   Motorola 'Moto G4 PLUS' (XT1641) Black, UNLOCKED
# 114907   Motorola 'Moto G4 PLUS' (XT1641) Black, UNLOCKED
# 114908                     Motorola Moto G 4 Plus - Black
# 114909                     Motorola Moto G 4 Plus - Black
# 114910  Moto G Plus XT1644 4th Gen. 64GB Smartphone (U...
# 114911                     Motorola Moto G 4 Plus - Black
# 114912                     Motorola Moto G 4 Plus - Black
# 114913                     Motorola Moto G 4 Plus - Black
# 114914       Motorola Moto G Plus, 4th Gen (Black, 32 GB)
# 114915       Motorola Moto G Plus, 4th Gen (Black, 32 GB)
# 114916       Motorola Moto G Plus, 4th Gen (Black, 32 GB)
# 114917       Motorola Moto G Plus, 4th Gen (Black, 32 GB)
# 114918       Motorola Moto G Plus, 4th Gen (White, 32 GB)
# 114919       Motorola Moto G Plus, 4th Gen (White, 32 GB)
# 114920       Motorola Moto G Plus, 4th Gen (White, 32 GB)
# 114921       Motorola Moto G Plus, 4th Gen (White, 32 GB)
# 114922       Motorola Moto G Plus, 4th Gen (White, 32 GB)
# 114923       Motorola Moto G Plus, 4th Gen (White, 32 GB)
# 114924       Motorola Moto G Plus, 4th Gen (White, 32 GB)
#
# [114925 rows x 11 columns]
